# %%
import torch as t
import numpy as np
np_arr=np.array([2,3])
pyt=torch.from_numpy(np_arr)
print(pyt)
np_arr1= pyt.numpy()
print(np_arr1)

# %%
import numpy as np
a_list=np.array([[1,4,0,1],
                 [4,2,8,4],
                 [2,3,1,9],
                 [2,3,1,9]],dtype=object)
print(a_list[:,:-1])
print("================================")
print(a_list[0:,-1])
print("================================")
print(a_list[:-2:2,::])
